# %%
import pandas as pd
import numpy as np

# %%
label = ['a','b','c']
my_list = [1,2,3]

arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(my_list, index = label)
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# DATA FRAMES

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'name':['ayush','anya','megha ', 'priya'],
    'age':[18,22,12,37],
    'city':['london', 'patna','bihar', 'delhi'],
    'salary': [12000000,2300,20200,2889300]
    
    
}

df =pd.DataFrame(data)

# %%
data_list= [
    ['ayush',19,'new york',12000000],
    ['shivam',18,'new york',1200000],
    ['diksha',20,'london',12000],
]



df2 =  pd.DataFrame(data_list)
columns = ["name", "age","city","salary"]

df2 =  pd.DataFrame(data_list,columns=columns)

# %% [markdown]
# SELECTION AND INDEXING OF COLUMNS

# %%
df[['name','city']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df2[['name','city']]
#
# File c:\CODING\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\CODING\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# ...

# %% [markdown]
# CREATING A NEW COLUMNS

# %%
df2["designation"] = ["doctor", "eng", "doc"]

# %%
df2
# Out:
#      name  age
# 0   ayush   19
# 1  shivam   18
# 2  diksha   20

# %% [markdown]
# REMOVE A COLUMN

# %%
df2
# Out:
#      name  age
# 0   ayush   19
# 1  shivam   18
# 2  diksha   20

# %% [markdown]
# CONDITIONAL SELECTION

# %%
df2[df2["age"]>18]
# Out:
#      name  age
# 0   ayush   19
# 2  diksha   20

# %%
df2[df2["age"]>18 & df2[""]]
