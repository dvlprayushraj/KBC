# %%
import numbers as np
import pandas as pd

# %% [markdown]
# merge 2 data frame

# %%
df1_merge = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
})


df2_merge = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Salary': [50000, 60000, 70000]
})

# %%
df1_merge
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df2_merge
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   70000

# %% [markdown]
# commmon id ke badaulat krn hoga jo krna hoga

# %%
pd.merge(df1_merge, df2_merge, on='Name',how='inner')
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
pd.merge(df1_merge, df2_merge, on='Name',how='outer')
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %% [markdown]
# concanitation of two numbers

# %%
df1_merge = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
})


df2_merge = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Salary': [50000, 60000, 70000]
})

# %%
pd.concat([df1_merge, df2_merge],axis= 1)
# Out:
#       Name  Age     Name  Salary
# 0    Alice   25    Alice   50000
# 1      Bob   30      Bob   60000
# 2  Charlie   35  Charlie   70000

# %% [markdown]
# joining two data frames

# %%
df3 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
})

df4= pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    
    })

# %%
df3.join(df4, how='outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df3.join(df4, how='outer')
#
# NameError: name 'df3' is not defined
