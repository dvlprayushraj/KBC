# %%
import numpy as np

# %%
a = np.array([0,1,np.nan,np.inf])

print("original array")
print(a)



print("Test a given array element-wise for finiteness :")

print(np.isnan(a))
# Out:
# original array
# [ 0.  1. nan inf]
# Test a given array element-wise for finiteness :
# [False False  True False]

# %%
arr1 = np.array([1,2])
arr2 = np.array([3,4])


print("original arrays:")
print(arr1)
print(arr2)



print("compresion grater :")
print(np.greater(arr1,arr2))


print("compression - grater_equal:")
print(np.greater_equal(arr1,arr2))
# Out:
# original arrays:
# [1 2]
# [3 4]
# compresion grater :
# [False False]
# compression - grater_equal:
# [False False]
